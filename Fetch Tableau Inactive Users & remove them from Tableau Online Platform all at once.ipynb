# %% [markdown]
# # Use Tableau API library to fetch inactive Tableau users from Tableau Online & deactivate their profiles from the platform all at once.
#
#  * Developed by: Kiran Kaushal Kopalley
#  * Idea: Kiran Kaushal Kopalley
#  * Date Implemented: 10/01/2022
#  * Last Change Description:
#  * Last Changed on:

# %% [markdown]
# #### 1. Initializing the libraries required for our script.

# %%
from tableau_api_lib import TableauServerConnection
from tableau_api_lib.utils import flatten_dict_column, querying
import pandas as pd

# %% [markdown]
# #### 2. Setting up the Configuration which will have all the information related to the Tableau Online connection, this is a parameter which will be consumed by 'TableauServerConnection' constructor
#
# Note: Personal Access Token needs to be created in Tableau Online under settings; this is unique for Tableau Admin

# %%
tableau_config = {
    'tableau_online': {
        'server': 'https://10ay.online.tableau.com',
        'api_version': '3.18',
        'personal_access_token_name':'KK Token',
        'personal_access_token_secret':'JVoJ3yxdSlqRbTeqVMwp2w==:M76dgARVjad9t0X4w4SitVY7RSJW3NsS',
        'site_name': 'prmiinsights',
        'site_url': 'prmiinsights'
    }
}

# %% [markdown]
# #### 3. Creating a connection variable and signing into PRMI Tableau Online Server
#
# General HTML Status Codes are linked [here](https://www.restapitutorial.com/httpstatuscodes.html)
#
# * The HTTP 200 indicates that the request has succeeded

# %%
conn=TableauServerConnection(tableau_config ,env='tableau_online')
response=conn.sign_in()
response
# Out:
# <Response [200]>

# %% [markdown]
# #### 4. Read info of all Tableau users within our Online Server, who haven't logged in yet and write into a dataframe

# %%
users_df = querying.get_users_dataframe(conn)
users_df = users_df[['fullName', 'email','authSetting', 'siteRole', ]]
#users_df.to_excel('Tableau Users.xlsx')
#users_df = users_df[users_df['lastLogin'].isna()]
users_df.to_excel("Tableau Users.xlsx")

# %%
users_df
# Out:
#                                    fullName  \
# 0                    Tableau System Account
# 1                    mbolleddu@primeres.com
# 2                    kkopalley@primeres.com
# 3                              Alicia Irwin
# 4                                Mary hatch
# ..                                      ...
# 282                manh.nguyen@primeres.com
# 283               sdepalantino@primeres.com
# 284  christopher_frost@frostmortgageusa.com
# 285         chris_wood@frostmortgageusa.com
# 286                      cbell@primeres.com
#
#                                               email  \
# 0    tol.admin.api.broker.service.usera@tableau.com
# 1                            mbolleddu@primeres.com
# 2                            kkopalley@primeres.com
# 3                               airwin@primeres.com
# 4                               mhatch@primeres.com
# ..                                              ...
# 282                        manh.nguyen@primeres.com
# 283                       sdepalantino@primeres.com
# 284          christopher_frost@frostmortgageusa.com
# 285                 chris_wood@frostmortgageusa.com
# 286                              cbell@primeres.com
#
#                                        id                  siteRole  \
# 0    e6dcd20e-21be-4973-80fa-4a2201195722       ServerAdministrator
# 1    05c5c6c8-80eb-49cb-b4ac-ea10954e907b  SiteAdministratorCreator
# 2    5c5ffb75-507f-4a1e-9e57-81453f3538be  SiteAdministratorCreator
# 3    3a3ec0eb-5849-4f50-999d-4c10590efd7d                    Viewer
# 4    6f87ab00-4cf5-4f97-913a-49743673a078                    Viewer
# ..                                    ...                       ...
# 282  1fa1cbc0-8e70-480a-9316-111e976dee26                    Viewer
# 283  3e55dbdc-dce6-4a8d-aa67-4a3f85f7282b                    Viewer
# 284  07907416-9d56-4772-be17-cbae1b4b3d86                    Viewer
# 285  649351bf-acdc-49fe-9b6d-083e0f1de1bc                    Viewer
# 286  3b5b3a37-5232-43f0-aade-57ed3a41a797                    Viewer
#
#                 lastLogin
# 0    2022-11-21T16:01:48Z
# 1    2022-11-21T20:00:03Z
# 2    2022-11-21T20:23:35Z
# 3    2022-11-21T20:16:36Z
# 4    2022-11-21T18:07:24Z
# ..                    ...
# 282                   NaN
# 283                   NaN
# 284  2022-10-14T21:08:12Z
# 285  2022-10-31T13:43:28Z
# 286  2022-11-21T17:31:06Z
#
# [287 rows x 5 columns]

# %% [markdown]
# #### 5. Write the data to a CSV file

# %%
users_df.to_csv('Inactive Tableau Users.csv')

# %% [markdown]
# #### 6. Read info of all Inactive Users from CSV file into a new dataframe variable

# %%
new_user_df = pd.read_csv('Test accounts.csv')

# %% [markdown]
# #### 7. Initialize responses list to capture the html handshakes for each record found in CSV file

# %%
responses=[]

# %% [markdown]
# #### 8. This loop will remove all the users present in the list from the Tableau Online platform

# %%
for index, row in new_user_df.iterrows():
    response = conn.remove_user_from_site(user_id=row['id'])
    responses.append(response)

# %% [markdown]
# #### 9. Outputs the response of all the handshakes between our code (Client) and Tableau Online (Server)
#
# General HTML Status Codes are linked [here](https://www.restapitutorial.com/httpstatuscodes.html)
#
# The HTTP 204 No Content success status response code indicates that a request has succeeded, but that the client doesn't need to navigate away from its current page.

# %%
responses
# Out:
# [<Response [204]>, <Response [204]>]

# %%
import pyodbc
server = 'wsdatawarehouseprod.sql.azuresynapse.net'
database = 'dpdatawarehouse'
username = 'ReportingUser'
password = 'DNp^R3VjHr_G6fzM'   
driver= '{ODBC Driver 17 for SQL Server}'


with pyodbc.connect('DRIVER='+driver+';SERVER=tcp:'+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password) as conn:
    with conn.cursor() as cursor:
        #query = cursor.execute("SELECT * FROM DIM.EmployeeUltiPro WHERE TerminationDate IS NOT NULL")
        query = "SELECT * FROM DIM.EmployeeUltiPro WHERE TerminationDate IS NOT NULL"
        data = pd.read_sql(query, conn)
        #row = cursor.fetchone()
        #while row:
            #print (row)
            #row = cursor.fetchone()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
data
# Out:
#      UltiproID          LastName FirstName MiddleName PreferredFirstName  \
# 0         5044         McCullagh     Brian       None               None
# 1        11014  Veguilla-Dejesus      Jose       None               None
# 2         5648          Williams    Daniel       None               None
# 3        11614          Campbell     Susan       None               None
# 4         9455             White     Riley       None               None
# ...        ...               ...       ...        ...                ...
# 6277     10556           Daniels    Xavier       None               None
# 6278      1931          Nakasone     Wayde       None               None
# 6279      6544             Bauer      Dirk       None               None
# 6280     14872      Gebremichael    DeAnna       None               None
# 6281     13086         McDermott      Mark       None               None
#
#                 FullNameFML             FullNameLFM        PreferredNameFL  \
# 0           Brian McCullagh        McCullagh, Brian        Brian McCullagh
# 1     Jose Veguilla-Dejesus  Veguilla-Dejesus, Jose  Jose Veguilla-Dejesus
# 2           Daniel Williams        Williams, Daniel        Daniel Williams
# 3            Susan Campbell         Campbell, Susan         Susan Campbell
# 4               Riley White            White, Riley            Riley White
# ...                     ...                     ...                    ...
# 6277         Xavier Daniels         Daniels, Xavier         Xavier Daniels
# 6278         Wayde Nakasone         Nakasone, Wayde         Wayde Nakasone
# 6279             Dirk Bauer             Bauer, Dirk             Dirk Bauer
# 6280    DeAnna Gebremichael    Gebremichael, DeAnna    DeAnna Gebremichael
# 6281         Mark McDermott         McDermott, Mark         Mark McDermott
#
#      CostCenter Department  ... CountryCode  FLSAStatus IsOriginator  \
# 0          2168             ...         USA  Non-Exempt   1
# 1          4530             ...         USA  Non-Exempt   1
# 2          2210             ...         USA        None         None
# 3          1000        994  ...         USA      Exempt   0
# 4          1000        994  ...         USA  Non-Exempt   0
# ...         ...        ...  ...         ...         ...          ...
# 6277       1000        994  ...         USA  Non-Exempt   0
# 6278       1008             ...         USA        None   1
# 6279       1000        975  ...         USA  Non-Exempt   0
# 6280       1004             ...         USA  Non exempt   0
# 6281       1000        971  ...         USA  Non-Exempt   0
#
#      SupervisorEmployeeNumber EepEEID        TerminationReason  \
# 0                        1208    None                     None
# 1                        1104    None                     None
# 2                        2075    None                     None
# 3                        6073    None              Performance
# 4                        3639    None                     None
# ...                       ...     ...                      ...
# 6277                    11698    None   Violation of Rules/Reg
# 6278                       82    None                     None
# 6279                      547    None            Abandoned Job
# 6280                    10755    None  Excessive absence/tardy
# 6281                     9941    None             Lack of work
#
#      TerminationType                                            RowHash  \
# 0               None  b"\x99'?\x14\x01d\xba\xcdOzP!\x13\xb5\x96B\xd1...
# 1               None  b'R\xfc\x11\x12_;\x93/\x084\xe2X\xfa\xaf\x95_f...
# 2               None  b'\x8du\xf5\xcbb$E\xe8\x0b$\xec\xc0\xc0\xc0\xa...
# 3        Involuntary  b'XI1C\x98\nh\x01\x87\xf0\xba)\x12Q\xf1\x9b\x1...
# 4               None  b'\xd8\xe4@\x01#\x9b\xb5\xcf@\xf5\xad\x0fX 9f\...
# ...              ...                                                ...
# 6277     Involuntary  b'K\xf4\x10sn\x84\x1a3,\x1c\x9a\xfc\xd5,\xeb\x...
# 6278            None  b'\x88\xb3\x0bG\xc7\xa6\x055>\xa0b\xf7eeW\xf7\...
# 6279       Voluntary  b"\xdd1\x9b\x9c\xaei\x88T\n\xaf<\xa9q\x82\x1d\...
# 6280     Involuntary  b'-\x90\xe95\x0c\x86\x0f\xd6\xa8\xf3\x94\x03\x...
# 6281     Involuntary  b'\xcacH2YP\xef\xe1\x08\xe5\xfc\xadp\x08!\x19Q...
#
#                  CreatedDate            ModifiedDate
# 0    2022-08-11 21:50:42.673 2022-08-25 12:37:22.967
# 1    2022-08-11 21:50:42.673 2022-08-25 12:37:22.967
# 2    2022-08-11 21:50:42.673 2022-08-25 12:37:22.967
# 3    2022-08-11 21:50:42.673 2022-08-23 12:36:46.800
# 4    2022-08-11 21:50:42.673 2022-08-25 12:37:22.967
# ...                      ...                     ...
# 6277 2022-08-11 21:50:42.673 2022-08-23 12:36:46.800
# 6278 2022-08-11 21:50:42.673 2022-08-25 12:37:22.967
# 6279 2022-08-11 21:50:42.673 2022-10-06 12:37:12.887
# 6280 2022-09-07 12:37:01.747 2022-10-07 12:37:24.723
# 6281 2022-08-11 21:50:42.673 2022-11-03 12:36:52.457
#
# [6282 rows x 39 columns]

# %%
finaldf = pd.merge(users_df, data, left_on='email', right_on='EmailAddress', how='left').drop('EmailAddress', axis=1)

# %%
finaldf.to_excel("Tableau Users Curated data.xlsx")

# %%
finaldf[finaldf['TerminationDate'].isna()]

# %%
finaldf.loc[finaldf['TerminationDate'].notnull()]
# Out:
#                       fullName                      email  \
# 6          tshoaf@primeres.com        tshoaf@primeres.com
# 15         aswope@primeres.com        aswope@primeres.com
# 33        grooker@primeres.com       grooker@primeres.com
# 37     jhutelmyer@primeres.com    jhutelmyer@primeres.com
# 58        anorman@primeres.com       anorman@primeres.com
# 69         bmacht@primeres.com        bmacht@primeres.com
# 70        bmineau@primeres.com       bmineau@primeres.com
# 80   christopherr@primeres.com  christopherr@primeres.com
# 110      ewalters@primeres.com      ewalters@primeres.com
# 115  gkerkbashian@primeres.com  gkerkbashian@primeres.com
# 118       gtaylor@primeres.com       gtaylor@primeres.com
# 135        Johoyt@primeres.com        johoyt@primeres.com
# 149        kkruel@primeres.com        kkruel@primeres.com
# 158       mmassey@primeres.com       mmassey@primeres.com
# 161       mshuler@primeres.com       mshuler@primeres.com
# 165       nquiroz@primeres.com       nquiroz@primeres.com
# 168      pohanlon@primeres.com      pohanlon@primeres.com
# 181         rreed@primeres.com         rreed@primeres.com
# 182       rsantos@primeres.com       rsantos@primeres.com
# 213         bhume@primeres.com         bhume@primeres.com
# 220       lrecord@primeres.com       lrecord@primeres.com
# 224        mautry@primeres.com        mautry@primeres.com
# 228       grogers@primeres.com       grogers@primeres.com
# 234   raitipamula@primeres.com   raitipamula@primeres.com
# 255      fmcclain@primeres.com      fmcclain@primeres.com
# 258        jboren@primeres.com        jboren@primeres.com
# 264     ssullivan@primeres.com     ssullivan@primeres.com
# 270    mikemorgan@primeres.com    mikemorgan@primeres.com
# 275     tbrooking@primeres.com     tbrooking@primeres.com
#
#                                        id siteRole             lastLogin  \
# 6    23fc416b-d099-437e-8c60-31b8eaa698f1   Viewer  2022-10-10T17:13:51Z
# 15   6897869b-3175-4e54-ad26-42c1707d6f56   Viewer  2022-10-28T15:30:14Z
# 33   3005ca6b-2b7f-417a-8e8f-3a7a90a844ee   Viewer  2022-09-20T17:15:19Z
# 37   c2b0e9ee-5315-4dac-9a46-7128dad25943   Viewer                   NaN
# 58   3a48cba4-8397-4f15-b6b9-f1280d159fde   Viewer                   NaN
# 69   e81fe82b-25c7-4d3b-af85-4aee0fde71de   Viewer                   NaN
# 70   2b99b504-2df8-4491-b208-79c131746b72   Viewer                   NaN
# 80   1750fc14-e0e6-4140-b4b6-0bff467f70d4   Viewer                   NaN
# 110  2a2bccbd-3779-4e6b-a4c5-67c84a069191   Viewer  2022-06-08T15:15:32Z
# 115  380eb151-20b5-4d7e-a0a8-5b3baf106258   Viewer  2022-01-04T22:31:15Z
# 118  4a3b2273-55e3-499f-ba55-1a6047bdeb8f   Viewer  2022-04-28T21:23:38Z
# 135  b6fc1b61-da72-4695-b57b-3fd8bf9ea38e   Viewer                   NaN
# 149  4f53b206-d42d-405f-8de3-9d7ec81b06e0   Viewer                   NaN
# 158  5e861a94-dc5f-4e8d-a8d0-4398ae254eac   Viewer                   NaN
# 161  d82b807e-e03c-433d-97b7-d92ae8f4892b   Viewer                   NaN
# 165  b1b1533f-9fcf-4322-ad87-cb0906eb52ac   Viewer                   NaN
# 168  c395854f-c54e-4dda-b564-01e136103aa3   Viewer  2022-06-15T17:38:38Z
# 181  09fa76ea-8573-4800-8c15-e54deddbfa3a   Viewer                   NaN
# 182  23128f7e-dd0b-4199-85c6-ff2467daf39b   Viewer                   NaN
# 213  29655caf-973f-4168-bf47-dffc1c55048c   Viewer  2022-10-21T22:51:51Z
# 220  e6542b70-86a3-4746-8196-0ffd408b161f   Viewer  2022-10-06T16:32:30Z
# 224  6e23d4ee-441f-459b-a07b-2e38230a2286   Viewer  2022-05-26T18:53:16Z
# 228  96d35a9d-5321-4111-836c-7393199f1cf6   Viewer  2022-06-23T18:11:44Z
# 234  eb08e35e-2413-4781-b5f3-653ccb554351   Viewer  2022-09-14T17:26:48Z
# 255  844b1b59-ebe0-4a48-a717-b7a5175124a6   Viewer  2022-09-08T18:42:06Z
# 258  a4e928aa-13b5-4f4a-adc5-512c6e8fe0b6   Viewer  2022-11-07T16:21:20Z
# 264  ae6ce38a-bc7d-43c1-b6ce-98c0f4074674   Viewer  2022-09-19T17:44:24Z
# 270  d4190792-ed4c-457c-8366-87c8761760a2   Viewer                   NaN
# 275  662816ca-fa26-4b84-8d86-f279204c885f   Viewer  2022-07-08T16:43:40Z
#
#     UltiproID     LastName    FirstName MiddleName PreferredFirstName  ...  \
# 6       14283        Shoaf         Trey       None               None  ...
# 15       2072        Swope       Andrew       None               None  ...
# 33       6511       Rooker        Geoff       None               None  ...
# 37       6525    Hutelmyer        James       None               None  ...
# 58         45       Norman      Alandro         D.               None  ...
# 69       5983        Macht     Benjamin       None               None  ...
# 70      12697       Mineau        Brian       None               None  ...
# 80      13061      Roberts  Christopher       None               None  ...
# 110      5676      Walters       Edward       None               None  ...
# 115     13986  Kerkbashian          Gil       None               None  ...
# 118     14063       Taylor       George       None               None  ...
# 135     12079       O'Hoyt        Jorge       None               None  ...
# 149      2032        Kruel        Kelli          R               None  ...
# 158      9633       Massey     Marshall       None               None  ...
# 161     13330       Shuler       Joseph       None               None  ...
# 165     14176       Quiroz      Natalia       None               None  ...
# 168     12647     O'Hanlon      Patrick       None               None  ...
# 181     12749         Reed      Richard       None               None  ...
# 182     12317       Santos        Ramon       None               None  ...
# 213       605         Hume    Brandilyn       None               None  ...
# 220     10159       Record     Lateesha       None               None  ...
# 224     10113        Autry     Mercedes       None               None  ...
# 228      5814       Rogers          Gay       None               None  ...
# 234     12525   Aitipamula       Ramesh       None               None  ...
# 255     12556      McClain        Faith       None               None  ...
# 258     11684        Boren         Joey       None               None  ...
# 264      9203     Sullivan       Shanon       None               None  ...
# 270     10470       Morgan      Michael       None               None  ...
# 275      1839     Brooking        Terri       None               None  ...
#
#     CountryCode  FLSAStatus IsOriginator SupervisorEmployeeNumber EepEEID  \
# 6           USA      Exempt   0                              3082    None
# 15          USA      Exempt   0                             12124    None
# 33          USA      Exempt   1                               137    None
# 37          USA      Exempt   1                               137    None
# 58          USA  Non-Exempt   1                              1247    None
# 69          USA      Exempt   1                               137    None
# 70          USA      Exempt   1                             11715    None
# 80          USA      Exempt   1                             12608    None
# 110         USA      Exempt   1                              9387    None
# 115         USA      Exempt   1                               137    None
# 118         USA  Non-Exempt   0                               137    None
# 135         USA  Non-Exempt   1                              9448    None
# 149         USA  Non-Exempt   1                                 3    None
# 158         USA      Exempt   1                               137    None
# 161         USA      Exempt   1                              1194    None
# 165         USA  Non-Exempt   1                             12300    None
# 168         USA  Non-Exempt   1                              9387    None
# 181         USA      Exempt   1                              1194    None
# 182         USA  Non-Exempt   1                              9387    None
# 213         USA      Exempt   0                             12124    None
# 220         USA  Non-Exempt   0                              6460    None
# 224         USA      Exempt   0                              3076    None
# 228         USA      Exempt   0                             12055    None
# 234         USA      Exempt   0                               517    None
# 255         USA      Exempt   1                             12599    None
# 258         USA  NON-EXEMPT   0                              3082    None
# 264         USA      Exempt   0                              3434    None
# 270         USA      Exempt   0                               137    None
# 275         USA  Non-Exempt   0                              5814    None
#
#     TerminationReason TerminationType  \
# 6        Lack of work     Involuntary
# 15       Lack of work     Involuntary
# 33          Other job       Voluntary
# 37          Other job       Voluntary
# 58             <None>       Voluntary
# 69             <None>       Voluntary
# 70        Performance     Involuntary
# 80    Location Closed     Involuntary
# 110      Lack of work     Involuntary
# 115         Other job       Voluntary
# 118      Lack of work     Involuntary
# 135      Lack of work     Involuntary
# 149      Lack of work     Involuntary
# 158            <None>       Voluntary
# 161   Personal/family       Voluntary
# 165         Other job       Voluntary
# 168      Lack of work     Involuntary
# 181   Personal/family       Voluntary
# 182       Performance     Involuntary
# 213      Lack of work     Involuntary
# 220     Abandoned Job       Voluntary
# 224   Personal/family       Voluntary
# 228      Lack of work     Involuntary
# 234      Lack of work     Involuntary
# 255      Lack of work     Involuntary
# 258            <None>       Voluntary
# 264      Lack of work     Involuntary
# 270   Location Closed     Involuntary
# 275      Lack of work     Involuntary
#
#                                                RowHash  \
# 6    b'\xa6\xe6\xfa\x9b\xa5\x0f\xe8FE\xcb\x08Zj1\x8...
# 15   b'\xfd3]\x8e\xfb\xff\x92\xebbJ(\x0b\xe0W\xf8S\...
# 33   b'\x01\x00\x1e6\xa2\xaac\xda\xb9\xc6\xb2\x7f\x...
# 37   b'\xc3\xae\xcel\xed\xefqyb)W5.\xfe1\x9d-\x98\x...
# 58   b'\xe2\xd7\xbe\ts\x8b\xcd\xbbT\x08\xf0\x07,E\x...
# 69   b'\xb0\xa5qI\xa9]Y\x88\x9f\xc58wx\x00\x1cv\xc1...
# 70   b'\xf2\x14\xa9w\x81\xb0\xabL\xcf9u\xaa\xbfXl\x...
# 80   b'\xcb&\x862\x99t\xec\x87l\x82r<\xf5,Mou\xbe\x...
# 110  b'\x18\xb8\xa8\xd1#{B\xff\xfb~\x84v\xc2\xbb\x8...
# 115  b'\x9e\xa6zi\xb6\xa4K\x9c+\xfa\xea\nFW\xfc\xe1...
# 118  b'[\xf3q\xd8\xcf\xaaq.\xb6\xc3\t\x15\x88\x12\x...
# 135  b'b\x06)S\xaf\x0b\x12\xc8\xd8\xc0Ie\x8e\x93\xf...
# 149          b'7;\xfe\xf8~W\x99\xc8]n-dU\xealB\xc5F,B'
# 158  b'LY\x80\xd5\xa2\x9f\x95\xad\x14S>yu$\xde`\xd0...
# 161  b'\xe9e\xf3U\x9c\xb4\x02\xa2\xe5\xe5t[\xabI\xc...
# 165  b'08\x189\xa7|{\xdd{\xaf\x9d\xac\x89@d\x94\xa3...
# 168  b'\x89+\x9e\x058\\M\xe4\x0e\xfb\xd6\x07\r\xbf\...
# 181  b'\xdb\xd1\xe0KI\xa6\x92\xbf\xdb\xcbk1UI\xda\x...
# 182  b'=h\xcf\xce\xd4\x84\x00K\x977t\xd3r\xfb\xea\x...
# 213  b'\xf6\xc9[\xadq\xf5\xbc\x1e\x92\xec3\x1d4\xb2...
# 220  b'M\x04,\x10\x1b\x11\xae\xfd\xc2\t\xf4a\x7frC)...
# 224  b'\xdd\xee?\xb3\x8f\xf0\xb8}\x17\xca\x94`\x91\...
# 228  b'h\x8d\xbd% po\xbf\x18\xbe(\xaa\x83c\xd5\xe16...
# 234  b'\xe3\xc1\xb1v\x8d\xbfE]\xd9\xbfe\xc2D=\x8c\t...
# 255  b'=\xbb\x0e>\xdf\rs)\x16\xecG\xf8\xcd\xa8\xb5\...
# 258  b'nw\x8ev\x7f\x96\xc3.\x0cv\xbc|\xce\x0b\xc1Y7...
# 264  b'\x93\xe9\xaf,\r\x9f\x1f\x13\xa7\xf3t\xf43\xe...
# 270  b',k<\x1a\xca\xb0\xfb\xcc\\UC\xfc\xc3\x83\xd9%...
# 275  b'\xfa\xf4\xf8-\xa9\xc9\xde*\x1a-\xbbk\x9ek\x8...
#
#                 CreatedDate            ModifiedDate
# 6   2022-08-11 21:50:42.673 2022-10-17 12:37:46.353
# 15  2022-08-11 21:50:42.673 2022-11-04 12:36:56.420
# 33  2022-08-11 21:50:42.673 2022-10-18 12:37:29.900
# 37  2022-08-11 21:50:42.673 2022-10-18 12:37:29.900
# 58  2022-08-11 21:50:42.673 2022-11-11 20:37:01.580
# 69  2022-08-11 21:50:42.673 2022-10-17 12:37:46.353
# 70  2022-08-11 21:50:42.673 2022-08-23 12:36:46.800
# 80  2022-08-11 21:50:42.673 2022-10-20 12:37:10.283
# 110 2022-08-11 21:50:42.673 2022-10-26 12:37:20.950
# 115 2022-08-11 21:50:42.673                     NaT
# 118 2022-08-11 21:50:42.673 2022-10-20 12:37:10.283
# 135 2022-08-11 21:50:42.673 2022-11-11 20:37:01.580
# 149 2022-08-11 21:50:42.673 2022-11-11 20:37:01.580
# 158 2022-08-11 21:50:42.673 2022-11-03 12:36:52.457
# 161 2022-08-11 21:50:42.673                     NaT
# 165 2022-08-11 21:50:42.673                     NaT
# 168 2022-08-11 21:50:42.673 2022-10-26 12:37:20.950
# 181 2022-08-11 21:50:42.673 2022-09-14 12:37:05.620
# 182 2022-08-11 21:50:42.673                     NaT
# 213 2022-08-11 21:50:42.673 2022-11-07 13:37:17.963
# 220 2022-08-11 21:50:42.673 2022-10-11 12:37:57.593
# 224 2022-08-11 21:50:42.673 2022-08-23 12:36:46.800
# 228 2022-08-11 21:50:42.673 2022-10-17 12:37:46.353
# 234 2022-08-11 21:50:42.673 2022-11-04 12:36:56.420
# 255 2022-08-11 21:50:42.673 2022-11-11 20:37:01.580
# 258 2022-08-11 21:50:42.673 2022-11-11 20:37:01.580
# 264 2022-08-11 21:50:42.673 2022-10-20 12:37:10.283
# 270 2022-08-11 21:50:42.673 2022-10-18 12:37:29.900
# 275 2022-08-11 21:50:42.673 2022-10-11 12:37:57.593
#
# [29 rows x 43 columns]
